# %%
import matplotlib.pyplot as plt

# %%
day = [1,2,3,4,5,6,7]
no1 = [2,3,1,4,5,3,6]
no2 = [4,7,2,3,1,8,2]

# %%
plt.scatter(day,no1)
plt.scatter(day,no2)
plt.title("Meet Gandhi")
plt.xlabel("day")
plt.ylabel("number")
plt.show()
