# %%
import pandas as pd
import numpy as np

# %%
movie = pd.read_csv('Movie.csv', encoding='latin1')
movie = movie.iloc[:,1:]
movie.head(3)
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
#
# ...

# %%
director = movie.groupby('Director')
director

# %%
len(movie)
# Out:
# 1000

# %%
len(director)
# Out:
# 548

# %%
director.size().sort_values(ascending=False)
# Out:
# Director
# Alfred Hitchcock     14
# Steven Spielberg     13
# Hayao Miyazaki       11
# Martin Scorsese      10
# Akira Kurosawa       10
#                      ..
# Jessie Nelson         1
# Jeong-beom Lee        1
# Jemaine Clement       1
# Jeethu Joseph         1
# Ãmer Faruk Sorak     1
# Length: 548, dtype: int64

# %%
director.groups
# Out:
# {'Aamir Khan': [65], 'Aaron Sorkin': [612], 'Abdellatif Kechiche': [734], 'Abhishek Chaubey': [577], 'Abhishek Kapoor': [735], 'Adam Elliot': [229], 'Adam McKay': [600], 'Aditya Chopra': [258], 'Aditya Dhar': [129], 'Akira Kurosawa': [31, 77, 121, 172, 181, 189, 294, 301, 303, 412], 'Alain Resnais': [551], 'Alan J. Pakula': [536], 'Alan Parker': [272, 676, 987], 'Alejandro AmenÃ¡bar': [372, 804, 948], 'Alejandro G. IÃ±Ã¡rritu': [244, 343, 733, 938], 'Alejandro Jodorowsky': [537], 'Alex Garland': [764], 'Alex Proyas': [959], 'Alexander Mackendrick': [440, 869], 'Alexander Payne': [739], 'Alfonso CuarÃ³n': [506, 513, 720, 745, 813, 946], 'Alfonso Gomez-Rejon': [732], 'Alfred Hitchcock': [49, 81, 118, 119, 187, 312, 450, 556, 559, 712, 714, 862, 998, 999], 'Amit Ravindernath Sharma': [322], 'Anders Thomas Jensen': [630], 'Andrei Tarkovsky': [174, 282, 286, 290, 296], 'Andrew Adamson': [651], 'Andrew Davis': [663], 'Andrew Lau': [375], 'Andrew Niccol': [654, 931], 'Andrew Stanton': [66, 
# ...

# %%
movie.iloc[64,:]
# Out:
# Series_Title                                              3 Idiots
# Released_Year                                                 2009
# Certificate                                                     UA
# Runtime                                                    170 min
# Genre                                                Comedy, Drama
# IMDB_Rating                                                    8.4
# Overview         Two friends are searching for their long lost ...
# Meta_score                                                    67.0
# Director                                           Rajkumar Hirani
# Star1                                                   Aamir Khan
# Star2                                                     Madhavan
# Star3                                                   Mona Singh
# Star4                                                Sharman Joshi
# No_of_Votes                                                 344445
# ...

# %%
director.get_group('Rajkumar Hirani')
# Out:
#              Series_Title Released_Year Certificate  Runtime  \
# 64               3 Idiots          2009          UA  170 min
# 207                    PK          2014          UA  153 min
# 233  Lage Raho Munna Bhai          2006           U  144 min
# 238   Munna Bhai M.B.B.S.          2003           U  156 min
#
#                       Genre  IMDB_Rating  \
# 64            Comedy, Drama          8.4
# 207  Comedy, Drama, Musical          8.1
# 233  Comedy, Drama, Romance          8.1
# 238  Comedy, Drama, Musical          8.1
#
#                                               Overview  Meta_score  \
# 64   Two friends are searching for their long lost ...        67.0
# 207  An alien on Earth loses the only device he can...         NaN
# 233  Munna Bhai embarks on a journey with Mahatma G...         NaN
# 238  A gangster sets out to fulfill his father's dr...         NaN
#
#             Director        Star1           Star2        Star3          Star4  \
# ...

# %%
director.sum()
# Out:
#                                           Series_Title Released_Year  \
# Director
# Aamir Khan                            Taare Zameen Par          2007
# Aaron Sorkin                The Trial of the Chicago 7          2020
# Abdellatif Kechiche                    La vie d'AdÃ¨le          2013
# Abhishek Chaubey                           Udta Punjab          2016
# Abhishek Kapoor                            Kai po che!          2013
# ...                                                ...           ...
# Zack Snyder                                300Watchmen      20062009
# Zaza Urushadze                             Mandariinid          2013
# Zoya Akhtar          Zindagi Na Milegi DobaraGully Boy      20112019
# Ãagan Irmak                            Babam ve Oglum          2005
# Ãmer Faruk Sorak                             G.O.R.A.          2004
#
#                     Certificate         Runtime  \
# Director
# Aamir Khan                    U         165 min
# ...

# %%
director.describe()
# Out:
#                                               Average Rating                   \
#                                                        count   mean       std
# Director
# A.L. Vijay                                               1.0  8.200       NaN
# A.R. Murugadoss                                          4.0  7.775  0.394757
# Aamir Khan, Amole Gupte                                  1.0  8.300       NaN
# Aanand L. Rai                                            2.0  7.600  0.000000
# Aaron Sorkin                                             2.0  7.550  0.212132
# ...                                                      ...    ...       ...
# Ãmer Vargi                                              2.0  7.950  0.212132
# ÃmÃ¼r Atay, Selim Demirdelen, Kudret Sabanci            1.0  7.300       NaN
# Ãzcan Alper                                             1.0  7.700       NaN
# Ãzer Feyzioglu                                          1.0  8.200       NaN
# ...
